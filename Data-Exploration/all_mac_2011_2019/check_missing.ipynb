# %%
import pandas as pd
df = pd.read_csv('/home/peder/git/fish-forecast/inspect/mac_filtered.csv', sep=';')
# df.head(10)

df_missing = df['date'].isnull()
df[df_missing == True]
# Out:
#       Starttidspunkt  Startposisjon bredde  Startposisjon lengde  \
# 4353      10.06.2014                67.900                13.717
# 10663     26.10.2018                59.390                -0.429
# 13301     26.06.2021                68.533                14.317
# 15924     19.10.2021                62.750                 4.383
# 18977     23.09.2022                63.353                 0.569
# 19015     24.09.2022                62.917                 1.400
# 19162     28.09.2022                62.450                 1.600
#
#             Stopptidspunkt  Stopposisjon bredde  Stopposisjon lengde  \
# 4353   10.06.2014 01:00:00               67.900               13.717
# 10663  26.10.2018 02:06:00               59.354               -0.442
# 13301  26.06.2021 01:06:00               68.667               14.350
# 15924  19.10.2021 00:17:00               62.750                4.383
# 18977  23.09.2022 01:37:00               63.302                0.590
# ...

# %%
import xarray as xr
ds = xr.open_dataset('/home/peder/git/fish-forecast/inspect/2011_01_12.nc')
print(ds)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/git/fish-forecast/.venv/lib/python3.10/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~/git/fish-forecast/.venv/lib/python3.10/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/home/peder/git/fish-forecast/inspect/2011_01_12.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), 'ea895629-5ba9-46b3-8020-8b60324ae13d']
#
# During handling of the above exception, another exception occurred:
#
# ...
